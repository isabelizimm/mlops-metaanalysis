# %%
import json

def make_file_list() -> list:
    files = list()
    i = 1
    while i < 11:
        files.append('../data/repos/topic_mlops_pg_'+str(i)+'.json')
        if i < 2:
            files.append('../data/repos/topic_modelmanagement_pg_'+str(i)+'.json')
        i += 1
    return files

def merge_files(files: list):
    result = list()
    for file in files:
        with open(file, 'r') as input_file:
            result.extend(json.load(input_file).get("items"))

    with open('../data/repos/topic_combined.json', 'w') as output_file:
        json.dump(result, output_file)

merge_files(make_file_list())
with open("../data/repos/topic_combined.json", "r") as read_file:
    raw = json.load(read_file)

# %%
assert len(raw) == 1044

# %%
import pandas as pd
from siuba import *

df = pd.DataFrame(raw)

# %%
(df
    >> select(-_["url":"deployments_url"])
    >> filter(_.fork == False, _.private == False, _.open_issues > 0, _.license is not None)
    >> separate(_.full_name, ["org_name", "repo_name"], sep='/')
)
# Out:
#              id                           node_id  \
# 0     156157055  MDEwOlJlcG9zaXRvcnkxNTYxNTcwNTU=
# 1     240315046  MDEwOlJlcG9zaXRvcnkyNDAzMTUwNDY=
# 2     144863525  MDEwOlJlcG9zaXRvcnkxNDQ4NjM1MjU=
# 3     135673451  MDEwOlJlcG9zaXRvcnkxMzU2NzM0NTE=
# 4     192640529  MDEwOlJlcG9zaXRvcnkxOTI2NDA1Mjk=
# ...         ...                               ...
# 1005  534175875                      R_kgDOH9bggw
# 1008  336675932  MDEwOlJlcG9zaXRvcnkzMzY2NzU5MzI=
# 1015  477140264                      R_kgDOHHCVKA
# 1026  389434090  MDEwOlJlcG9zaXRvcnkzODk0MzQwOTA=
# 1038  551666424                      R_kgDOIOHC-A
#
#                                            name  private  \
# 0                                  Made-With-ML    False
# 1                                          jina    False
# 2           awesome-production-machine-learning    False
# 3                                           nni    False
# 4                                  label-studio    False
# ...                                         ...      ...
# 1005                   lightning-hydra-template    False
# 1008                                  airjordan    False
# 1015                         DataWorkstation.jl    False
# 1026  Rossmann-Pharmaceuticals-Sales-prediction    False
# 1038                                      mlops    False
#
#                                                   owner  \
# 0     {'login': 'GokuMohandas', 'id': 8000987, 'node...
# 1     {'login': 'jina-ai', 'id': 60539444, 'node_id'...
# 2     {'login': 'EthicalML', 'id': 43532924, 'node_i...
# 3     {'login': 'microsoft', 'id': 6154722, 'node_id...
# 4     {'login': 'heartexlabs', 'id': 48309720, 'node...
# ...                                                 ...
# 1005  {'login': 'aiplaybookin', 'id': 83638338, 'nod...
# 1008  {'login': 'kevinmchan', 'id': 2401363, 'node_i...
# 1015  {'login': 'leferrad', 'id': 10536218, 'node_id...
# 1026  {'login': 'Azariagmt', 'id': 56393921, 'node_i...
# 1038  {'login': 'paulsilcock', 'id': 12411602, 'node...
#
#                                                html_url  \
# 0          https://github.com/GokuMohandas/Made-With-ML
# 1                       https://github.com/jina-ai/jina
# 2     https://github.com/EthicalML/awesome-productio...
# 3                      https://github.com/microsoft/nni
# 4           https://github.com/heartexlabs/label-studio
# ...                                                 ...
# 1005  https://github.com/aiplaybookin/lightning-hydr...
# 1008            https://github.com/kevinmchan/airjordan
# 1015     https://github.com/leferrad/DataWorkstation.jl
# 1026  https://github.com/Azariagmt/Rossmann-Pharmace...
# 1038               https://github.com/paulsilcock/mlops
#
#                                             description   fork  \
# 0     Learn how to responsibly develop, deploy and m...  False
# 1     🔮 Build multimodal AI services via cloud nativ...  False
# 2     A curated list of awesome open source librarie...  False
# 3     An open source AutoML toolkit for automate mac...  False
# 4     Label Studio is a multi-type data labeling and...  False
# ...                                                 ...    ...
# 1005  ML/DL Template with Hydra - DVC, Hyperparamete...  False
# 1008  An airflow pipeline for building and scoring N...  False
# 1015  A Julia framework to produce your data project...  False
# 1026  Time series sales forecast for Rossmann Pharma...  False
# 1038  A scratch space to experiment with MLOps techn...  False
#
#                 created_at            updated_at  ...  \
# 0     2018-11-05T03:44:27Z  2023-01-18T14:24:54Z  ...
# 1     2020-02-13T17:04:44Z  2023-01-18T14:18:14Z  ...
# 2     2018-08-15T14:28:41Z  2023-01-18T17:16:27Z  ...
# 3     2018-06-01T05:51:44Z  2023-01-18T12:49:05Z  ...
# 4     2019-06-19T02:00:44Z  2023-01-18T11:31:18Z  ...
# ...                    ...                   ...  ...
# 1005  2022-09-08T11:15:13Z  2022-12-03T14:02:39Z  ...
# 1008  2021-02-07T01:40:15Z  2021-03-29T03:47:21Z  ...
# 1015  2022-04-02T18:34:24Z  2022-08-14T20:34:58Z  ...
# 1026  2021-07-25T20:19:38Z  2021-08-04T11:02:24Z  ...
# 1038  2022-10-14T21:10:03Z  2022-10-29T15:14:53Z  ...
#
#                                                  topics visibility forks  \
# 0     [data-engineering, data-science, deep-learning...     public  5308
# 1     [aiops, airflow, cloud-native, creative-ai, cr...     public  2012
# 2     [awesome, awesome-list, data-mining, deep-lear...     public  1817
# 3     [automated-machine-learning, automl, bayesian-...     public  1736
# 4     [annotation, annotation-tool, annotations, bou...     public  1362
# ...                                                 ...        ...   ...
# 1005  [deep-learning, machine-learning, mlops, mlops...     public     0
# 1008            [airflow, etl-pipeline, ml, mlops, nba]     public     0
# 1015  [data-science, julia, machine-learning, mlops,...     public     0
# 1026  [data-analysis, mlops, regression, rossmann, t...     public     0
# 1038  [argo-workflows, docker, dvc, github-actions, ...     public     0
#
#      open_issues watchers default_branch  \
# 0              6    32107           main
# 1             33    17144         master
# 2             26    13008         master
# 3            290    12415         master
# 4            448    11747        develop
# ...          ...      ...            ...
# 1005           5        0           main
# 1008          13        0           main
# 1015           1        0           main
# 1026           1        0           main
# 1038           3        0           main
#
#                                             permissions  score      org_name  \
# 0     {'admin': False, 'maintain': False, 'push': Fa...    1.0  GokuMohandas
# 1     {'admin': False, 'maintain': False, 'push': Fa...    1.0       jina-ai
# 2     {'admin': False, 'maintain': False, 'push': Fa...    1.0     EthicalML
# 3     {'admin': False, 'maintain': False, 'push': Fa...    1.0     microsoft
# 4     {'admin': False, 'maintain': False, 'push': Fa...    1.0   heartexlabs
# ...                                                 ...    ...           ...
# 1005  {'admin': False, 'maintain': False, 'push': Fa...    1.0  aiplaybookin
# 1008  {'admin': False, 'maintain': False, 'push': Fa...    1.0    kevinmchan
# 1015  {'admin': False, 'maintain': False, 'push': Fa...    1.0      leferrad
# 1026  {'admin': False, 'maintain': False, 'push': Fa...    1.0     Azariagmt
# 1038  {'admin': False, 'maintain': False, 'push': Fa...    1.0   paulsilcock
#
#                                       repo_name
# 0                                  Made-With-ML
# 1                                          jina
# 2           awesome-production-machine-learning
# 3                                           nni
# 4                                  label-studio
# ...                                         ...
# 1005                   lightning-hydra-template
# 1008                                  airjordan
# 1015                         DataWorkstation.jl
# 1026  Rossmann-Pharmaceuticals-Sales-prediction
# 1038                                      mlops
#
# [368 rows x 45 columns]

# %% [markdown]
# Scope: looking at just tools.
#
# How to prove if something is an OSS tool?
#
# - has a license
# - has at least one open issue (probably not a strong criteria)
# - is public
#
# think of removing
#
# - lists such as "awesome mlops" esque
# - projects (will probably be at least partially removed with no license?)
#
#
# What other tags to collect?
#
# - mlops
# - model-management
#
# Other metrics to bring in?
#
# - contributors
